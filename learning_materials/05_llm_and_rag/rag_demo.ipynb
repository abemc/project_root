# %% [markdown]
# # RAG デモ - 学習用テンプレート
# このノートブックは小さな RAG（Retrieval-Augmented Generation）ワークフローの最小実装を示します。
# 目的: ドキュメントを埋め込み→インデックス化→簡単な検索→LLMで回答生成 の流れを学ぶ。

# %% [markdown]
# ## 1) 必要なパッケージ（例）
# 以下は一例です。実行環境に合わせてインストールしてください。
# ```bash
# pip install sentence-transformers faiss-cpu openai transformers torch
# ```

# %%
# 2) サンプルデータ (簡易)
docs = [
    {"id":"d1", "text":"Python の基礎: 変数、関数、ループ"},
    {"id":"d2", "text":"機械学習: 教師あり学習、評価指標"},
    {"id":"d3", "text":"RAG: 埋め込みを用いた検索と生成の組合せ"},
]
: 
,
: null,
: {},
: [],
: [
3
,
,
,
,
,
,
